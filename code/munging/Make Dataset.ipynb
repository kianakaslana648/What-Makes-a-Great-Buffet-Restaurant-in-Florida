# %%
import numpy as np
import pandas as pd

# %%
restaurant = pd.read_csv("../restaurant_df.csv")
buffet = restaurant[restaurant["categories"].str.contains("Buffet")]
print(len(buffet))
buffet.head(5)
florida_buffet = buffet[buffet["state"] == "FL"]
print(len(florida_buffet))
florida_buffet
# Out:
# 275
# 46
#                   business_id                                       name  \
# 3283   35GCFtezJ3upyqGf-zJ8MA                           Gateway To India
# 3700   f4PA-f1tcN1bIpZJLdFsQQ                               Deccan Spice
# 4747   ebjExMyGlSfz_JXwvBa27g                     Saffron Indian Cuisine
# 5171   _anAV7MH8kZ-KXI6hNjtHQ             Terra Mar Brazilian Steakhouse
# 5226   h0tUOsL3sRYVqSQlxWjW5g                  Minerva Indian Restaurant
# 6578   4xNBm3oGqSryXvvl2X3TuQ                     Shephard's Ocean Flame
# 8249   08zAKV1Sp-TIC_YVwBcBNw                    Fred's Southern Kitchen
# 8608   G8H-8KnMFjS4bHtTBX9t7A                             Hibachi Buffet
# 10074  kwC1oEbmYx4r3xLCd6rYSQ                                  Tung Tung
# 12173  o6JVQNT7CgO2PDyXPXBPXg                               Doc'S Grille
# 13498  bWl3Tf7kgV1NU6bcshsTkw                        Bermudas Restaurant
# 14663  U_xXDEstWkdhmQR8IWHVCw                               Asian Buffet
# ...

# %%
# buffet.to_csv("buffet.csv",index=False)

# %%
reviews = pd.read_csv("../review_aspect_attr.csv")
florida_reviews = florida_buffet.merge(reviews, on="business_id")
florida_reviews
# Out:
#                   business_id              name                 address  \
# 0      35GCFtezJ3upyqGf-zJ8MA  Gateway To India     8300 Bay Pines Blvd
# 1      35GCFtezJ3upyqGf-zJ8MA  Gateway To India     8300 Bay Pines Blvd
# 2      35GCFtezJ3upyqGf-zJ8MA  Gateway To India     8300 Bay Pines Blvd
# 3      35GCFtezJ3upyqGf-zJ8MA  Gateway To India     8300 Bay Pines Blvd
# 4      35GCFtezJ3upyqGf-zJ8MA  Gateway To India     8300 Bay Pines Blvd
# ...                       ...               ...                     ...
# 13955  G8H-8KnMFjS4bHtTBX9t7A    Hibachi Buffet  13151 N Dale Mabry Hwy
# 13956  G8H-8KnMFjS4bHtTBX9t7A    Hibachi Buffet  13151 N Dale Mabry Hwy
# 13957  G8H-8KnMFjS4bHtTBX9t7A    Hibachi Buffet  13151 N Dale Mabry Hwy
# 13958  G8H-8KnMFjS4bHtTBX9t7A    Hibachi Buffet  13151 N Dale Mabry Hwy
# 13959  G8H-8KnMFjS4bHtTBX9t7A    Hibachi Buffet  13151 N Dale Mabry Hwy
#
#                  city state  postal_code   latitude  longitude  stars  \
# ...

# %%
# florida_reviews.to_csv("florida_buffet_review.csv", index=False)

# %%
reviews = pd.read_csv("../buffet_reviews.csv")
buffet = reviews.merge(restaurant, on="business_id")
buffet
# Out:
# Empty DataFrame
# Columns: [review_id, user_id, business_id, stars_x, useful, funny, cool, text, date, name, address, city, state, postal_code, latitude, longitude, stars_y, review_count, is_open, attributes, categories, hours]
# Index: []
#
# [0 rows x 22 columns]

# %%
 Client ID

yy4aV7QcP0apY8BHet7U6Q

API Key

6EM_nW3pba-OBNdI-1VAsu9Ctj5nHpiJIv4vHpHEP2GUUD212iapjqb3aqEEP3eIOYY43saa7kr9ToRnQDQbN28C6RlfG6Rwh1DrHWKeNAOWxHjyiyZQo-HDmjtKYnYx

# %%
# This is needed to perform REST API calls
import requests
import json

# Developer API key
API_KEY= "6EM_nW3pba-OBNdI-1VAsu9Ctj5nHpiJIv4vHpHEP2GUUD212iapjqb3aqEEP3eIOYY43saa7kr9ToRnQDQbN28C6RlfG6Rwh1DrHWKeNAOWxHjyiyZQo-HDmjtKYnYx" 
 
# What you are searching for
DEFAULT_TERM = 'buffets'
# Business location
# DEFAULT_LOCATION = 'NE'
# Maximum number of results to return
SEARCH_LIMIT = 20
 
# Busines search end point
url = 'https://api.yelp.com/v3/businesses/search'
# Heahder should contain the API key
headers = {'Authorization': 'Bearer {}'.format(API_KEY)}
# Search parameters
data = []
offset = 0
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for DEFAULT_LOCATION in states:
    #print(i)
    url_params = {
        'location': DEFAULT_LOCATION, 
        'limit': 50,
        "categories":DEFAULT_TERM,
        "offset":offset,
        }

    # Call the API
    response = requests.request('GET', url, headers=headers, params=url_params)
    content = json.loads(response.content)["businesses"]
    print(len(content))
    data.extend(content)
    # print(len(data))
print(len(data))
# Out:
# 4
# 8
# 24
# 14
# 20
# 12
# 18
# 49
# 11
# 11
# 16
# 18
# 9
# 10
# 25
# 9
# 10
# 18
# 37
# 27
# 17
# 11
# 7
# 14
# 9
# 11
# 3
# 9
# 8
# 12
# 7
# 11
# 11
# 44
# 50
# 10
# 15
# 12
# 11
# 12
# 11
# 6
# 17
# 17
# 7
# 12
# 6
# 14
# 8
# 8
# 5
# 745

# %%
for DEFAULT_LOCATION in ["NY"]:
    #print(i)
    url_params = {
        'location': DEFAULT_LOCATION, 
        'limit': 50,
        "categories":DEFAULT_TERM,
        "offset":50,
        }

    # Call the API
    response = requests.request('GET', url, headers=headers, params=url_params)
    content = json.loads(response.content)["businesses"]
    print(len(content))
    data.extend(content)
# Out:
# 10

# %%
len(data)
# Out:
# 755

# %%
df = pd.DataFrame.from_records(data)
df
# Out:
#                          id                                     alias  \
# 0    bqLu256dlljANZHWdTVVMw   china-lights-oriental-cuisine-anchorage
# 1    JMH_XygDEGXzrIs_-2Lzpg          ding-how-mongolian-bbq-anchorage
# 2    sLMT0sfGhGINQkN983T3xA  golden-corral-buffet-and-grill-anchorage
# 3    qaHzSkkgt8wyeIXwrbcbWA                      pond-cafe-girdwood-2
# 4    bc_KxbktwYodnZq7pPUerQ                     bay-leaf-birmingham-8
# ..                      ...                                       ...
# 750  fPvdlKME3b5eI__A2Vw0LA                 5-borough-bistro-new-york
# 751  aerH0RTL3juqiLZbhwYVrw                      ginger-tree-no-title
# 752  EJPqwdHlr6smIgI5SFP6vg      khan-baba-restaurant-jackson-heights
# 753  Lx2iV2DMqJ4PVTSlO0pzDA                         pantries-new-york
# 754  KhzQ-9jzOLOtrKXSxoC-uw                   bombay-grill-new-york-2
#
#                               name  \
# 0    China Lights Oriental Cuisine
# 1           Ding How Mongolian BBQ
# ...

# %%
df.to_csv("fusion.csv",index=False)

# %%
biz_ids = list(set(df["id"]))
url = 'https://api.yelp.com/v3/businesses/search'
data = []
for biz in biz_ids:
    # Call the API
    url_params = {
        "offset":0,
        }
    url = f'https://api.yelp.com/v3/businesses/{biz}/reviews'
    response = requests.request('GET', url, headers=headers,params=url_params)
    print(json.loads(response.content))
    sys.exit()
    content = json.loads(response.content)["businesses"]
    print(len(content))
    data.extend(content)
# Out:
# {'reviews': [{'id': 'XBq5-7FGhxCx9wCKVBuKVw', 'url': 'https://www.yelp.com/biz/the-buffet-at-aria-las-vegas-5?adjust_creative=yy4aV7QcP0apY8BHet7U6Q&hrid=XBq5-7FGhxCx9wCKVBuKVw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=yy4aV7QcP0apY8BHet7U6Q', 'text': "Looking forward to this buffet to open again. \nThere's no good reason why it's still closed since the pandemic!\nExcellent food \nGood variety \nAffordable...", 'rating': 5, 'time_created': '2022-01-30 11:36:04', 'user': {'id': 'FDnDjXnW7yqb1HTtef40bA', 'profile_url': 'https://www.yelp.com/user_details?userid=FDnDjXnW7yqb1HTtef40bA', 'image_url': None, 'name': 'maher a.'}}, {'id': '1CSBdPbnjm8V8xLyfx7XWQ', 'url': 'https://www.yelp.com/biz/the-buffet-at-aria-las-vegas-5?adjust_creative=yy4aV7QcP0apY8BHet7U6Q&hrid=1CSBdPbnjm8V8xLyfx7XWQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=yy4aV7QcP0apY8BHet7U6Q', 'text': "Review of The Buffet at Aria\n\nAria's The Buffet is on my list of to
# ...

# %%
{'reviews': [{'id': 'XBq5-7FGhxCx9wCKVBuKVw', 'url': 'https://www.yelp.com/biz/the-buffet-at-aria-las-vegas-5?adjust_creative=yy4aV7QcP0apY8BHet7U6Q&hrid=XBq5-7FGhxCx9wCKVBuKVw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=yy4aV7QcP0apY8BHet7U6Q', 'text': "Looking forward to this buffet to open again. \nThere's no good reason why it's still closed since the pandemic!\nExcellent food \nGood variety \nAffordable...", 'rating': 5, 'time_created': '2022-01-30 11:36:04', 'user': {'id': 'FDnDjXnW7yqb1HTtef40bA', 'profile_url': 'https://www.yelp.com/user_details?userid=FDnDjXnW7yqb1HTtef40bA', 'image_url': None, 'name': 'maher a.'}}, {'id': '1CSBdPbnjm8V8xLyfx7XWQ', 'url': 'https://www.yelp.com/biz/the-buffet-at-aria-las-vegas-5?adjust_creative=yy4aV7QcP0apY8BHet7U6Q&hrid=1CSBdPbnjm8V8xLyfx7XWQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=yy4aV7QcP0apY8BHet7U6Q', 'text': "Review of The Buffet at Aria\n\nAria's The Buffet is on my list of top 3 buffets in Las Vegas!  All dishes enhanced to culinary delicacy!  And their selection...", 'rating': 5, 'time_created': '2021-03-28 14:15:13', 'user': {'id': 'h9SeCKbSyD93YQpgsGt6Hg', 'profile_url': 'https://www.yelp.com/user_details?userid=h9SeCKbSyD93YQpgsGt6Hg', 'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/TRzIADyYY3csANOuMWLEZA/o.jpg', 'name': 'ArchDuke Kenneth Khanh D.'}}, {'id': 'DmK-Y4meaxIyhw0Pe8zOMQ', 'url': 'https://www.yelp.com/biz/the-buffet-at-aria-las-vegas-5?adjust_creative=yy4aV7QcP0apY8BHet7U6Q&hrid=DmK-Y4meaxIyhw0Pe8zOMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=yy4aV7QcP0apY8BHet7U6Q', 'text': 'Despite being touted as the top 4 gourmet buffets in Las Vegas, I feel this buffet is bad. they do have a very modern and bright room for the buffet. \n\nFor...', 'rating': 2, 'time_created': '2020-03-05 11:19:10', 'user': {'id': '_zvOYwHK3Sf8Y8F7Tn2bdQ', 'profile_url': 'https://www.yelp.com/user_details?userid=_zvOYwHK3Sf8Y8F7Tn2bdQ', 'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/4pcnDPdWJqmkQq4QWdXX_g/o.jpg', 'name': 'Regis K.'}}], 'total': 2713, 'possible_languages': ['en', 'nl', 'fr', 'de', 'es', 'zh']}
# Out:
# 3
